# %% [markdown]
# ## DICTIONARY TO LIST THE PARAMETERS TO AUTOMATE ETL

# %%
my_array = [
    {"source_container": "bronze",
     "sink_container": "silver",
     "folder":"athletes"
     },
     {"source_container": "bronze",
     "sink_container": "silver",
     "folder":"coaches"
     },
    {"source_container": "bronze",
     "sink_container": "silver",
     "folder":"events"
     }
]

# %%
dbutils.jobs.taskValues.set(key = "my_output", value = my_array)
