# %% [markdown]
# ## silver notebook

# %% [markdown]
# ### reading nocs data from bronze

# %% [markdown]
# ## WE BRING NOCS FROM BRONZE TO SILVER ALONE BECAUSE WE PERFORM A TRANSFORMATION OF DATA THAT IS UNIQUE TO THIS TABLE

# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", True)\
    .load("abfss://bronze@olympicsprogectstorage.dfs.core.windows.net/nocs")
display(df)

# %% [markdown]
# ###dropping a column

# %%
df = df.drop("country")

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = df.withColumn("tag", split(col('tag'),'-')[0])
df.display()

# %% [markdown]
# ## saving nocs to silver with delta format

# %%
df.write.format("delta")\
    .mode("append")\
        .option("path", "abfss://silver@olympicsprogectstorage.dfs.core.windows.net/nocs")\
            .saveAsTable("olympicspariscatalog.silver.nocs")

# %%
df.write.format("delta")\
    .mode("append")\ #if you do not write the option path it will store it in the default path of the metastore ("unitymetastore" in adls)
        .saveAsTable("olympicspariscatalog.silver.nocs_man")
